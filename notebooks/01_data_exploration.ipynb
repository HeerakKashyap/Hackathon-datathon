# %% [markdown]
# # UDISE Data Exploration
#
# This notebook explores the structure and content of UDISE education datasets.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
# Load data
from src.data_processing import UDISEDataProcessor

processor = UDISEDataProcessor(data_dir='../data/raw')

# Process 2024-25 data
df_2024 = processor.process_all_data('2024-25')

# Process 2023-24 data
df_2023 = processor.process_all_data('2023-24')

# %%
# Explore data structure
if df_2024 is not None:
    print("2024-25 Dataset Shape:", df_2024.shape)
    print("\nColumn Names:")
    print(df_2024.columns.tolist())
    print("\nFirst few rows:")
    display(df_2024.head())
    print("\nData Types:")
    print(df_2024.dtypes)
    print("\nMissing Values:")
    print(df_2024.isnull().sum().sort_values(ascending=False).head(20))
