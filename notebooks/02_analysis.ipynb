# %% [markdown]
# # Education Policy Analysis
#
# This notebook performs in-depth analysis to derive policy insights.

# %%
import pandas as pd
import numpy as np
from src.analysis import EducationPolicyAnalyzer
from src.visualization import EducationVisualizer

# %%
# Load processed data
df = pd.read_csv('../data/processed/merged_2024-25.csv')

# Initialize analyzer
analyzer = EducationPolicyAnalyzer(df=df)
