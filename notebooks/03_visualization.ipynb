# %% [markdown]
# # Visualization and Dashboard Creation
#
# This notebook creates visualizations for the policy recommendations.

# %%
import pandas as pd
from src.visualization import EducationVisualizer

# %%
# Load processed data
df = pd.read_csv('../data/processed/merged_2024-25.csv')

# Initialize visualizer
visualizer = EducationVisualizer(df=df, output_dir='../visualizations')
